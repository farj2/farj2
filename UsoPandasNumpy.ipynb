# %%
import pandas as pd
import numpy as np

# %%
seriePrimos= pd.Series([1,3,5,7,11,13],index=["p1","p2","p3","p4","p5","p6"])
PrimosCuadrados= seriePrimos**2

# %%
seriePrimos
PrimosCuadrados
# Out:
# p1      1
# p2      9
# p3     25
# p4     49
# p5    121
# p6    169
# dtype: int64

# %%
PrimosGrandes=PrimosCuadrados.filter(PrimosCuadrados>49)

# %%
PrimosGrandes
# Out:
# Series([], dtype: int64)

# %%
mi_dic= df.mi_dic(("pos1"==21,"pos2"==32,"pos3"==43))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mi_dic= df.mi_dic(("pos1"==21,"pos2"==32,"pos3"==43))
#
# NameError: name 'df' is not defined

# %%
mi_dic.iloc("pos1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mi_dic.iloc("pos1")
#
# NameError: name 'mi_dic' is not defined

# %%
pd.read_csv('C:\Users\Usuario\Desktop\curso SENCE\Scripts\FirstStepsWithPandas.csv')
# Out:
#   Cell In[38], line 1
#     pd.read_csv('C:\Users\Usuario\Desktop\curso SENCE\Scripts\FirstStepsWithPandas.csv')
#                                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
